# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-10, 10, 121)
plt.plot(x, np.cos(x))
plt.plot(x, np.cos(2 * x))
plt.title("Два уравнения от cos(x) и cos(2x) ")
plt.show()
